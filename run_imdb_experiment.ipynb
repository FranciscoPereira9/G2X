# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install torch-scatter torch-sparse torch-cluster torch-spline-conv torch-geometric -f https://data.pyg.org/whl/torch-1.11.0+cu113.html
! pip install wandb
! pip install -U PyYAML
! pip install tqdm

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/G2X/imdb-word
# Out:
# /content/drive/MyDrive/Colab_Notebooks/G2X/imdb-word

# %%
import os
files = os.listdir("data/processed/train")
print("# Train files: ", len(files))
files = os.listdir("data/processed/test")
print("# Test files: ", len(files))
# Out:
# # Train files:  0
# # Test files:  0

# %%
#for i in files:
#  os.remove("/content/drive/MyDrive/Colab_Notebooks/G2X/imdb-word/data/processed/test/"+i)

# %%
# !python main.py # Run for Original

# %%
# !python main.py # Run for L2X
# Out:
# Loading dataset...
# Creating L2X Model...
# Loading L2X Model...
# L2X Model loaded.
# Compute efficiency: 0.84: 100% 391/391 [00:02<00:00, 167.46it/s]
# Test Acc: 0.8853
# Loading Explainer...
#  Explainer Model Loaded.
#  Generating Explanations...
# Compute efficiency: 0.30: 100% 391/391 [00:01<00:00, 200.55it/s]
# Explanations saved.
# Visualizing Explanations...
# ...

# %%
# !python main.py # Run for G2X
# Out:
# Loading dataset...
# Creating G2X Model...
# Training G2X Model...
# wandb: Currently logged in as: franciscop9. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.12.19
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab_Notebooks/G2X/imdb-word/wandb/run-20220626_224800-2q1580hu
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run deep-shadow-53
# wandb: ⭐️ View project at https://wandb.ai/franciscop9/G2X_PyTorch
# wandb: 🚀 View run at https://wandb.ai/franciscop9/G2X_PyTorch/runs/2q1580hu
# Using CUDA: True
# Compute efficiency: 0.40, epoch: 0/10:: 100% 391/391 [01:20<00:00,  4.87it/s]
# Epoch: 0  Train Loss: 0.6141  Train Acc: 0.6585
# Compute efficiency: 0.39, epoch: 1/10:: 100% 391/391 [01:07<00:00,  6.54it/s]Epoch: 1  Train Loss: 0.4876  Train Acc: 0.7810
# Compute efficiency: 0.39, epoch: 1/10:: 100% 391/391 [01:07<00:00,  5.82it/s]
# ...
